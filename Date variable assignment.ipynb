# %% [markdown]
# # Date variable assignment

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:/Users/PRASADH/OneDrive/Desktop/data sets/Sample - Superstore.xlsx")
# Out:
# C:\Users\PRASADH\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2698  CA-2016-145317 2016-03-18 2016-03-23  Standard Class    SM-20320
# 1    6827  CA-2018-118689 2018-10-02 2018-10-09  Standard Class    TC-20980
# 2    8154  CA-2019-140151 2019-03-23 2019-03-25     First Class    RB-19360
# 3    2624  CA-2019-127180 2019-10-22 2019-10-24     First Class    TA-21385
# 4    4191  CA-2019-166709 2019-11-17 2019-11-22  Standard Class    HL-15040
#
#   Customer Name      Segment Country/Region           City  ... Postal Code  \
# 0   Sean Miller  Home Office  United States   Jacksonville  ...     32216.0
# 1  Tamara Chand    Corporate  United States      Lafayette  ...     47905.0
# 2  Raymond Buch     Consumer  United States        Seattle  ...     98115.0
# 3  Tom Ashbrook  Home Office  United States  New York City  ...     10024.0
# 4  Hunter Lopez     Consumer  United States         Newark  ...     19711.0
#
# ...

# %%
df[["Order Date", "Ship Date"]]
# Out:
#      Order Date  Ship Date
# 0    2016-03-18 2016-03-23
# 1    2018-10-02 2018-10-09
# 2    2019-03-23 2019-03-25
# 3    2019-10-22 2019-10-24
# 4    2019-11-17 2019-11-22
# ...         ...        ...
# 9989 2016-09-26 2016-09-26
# 9990 2016-03-31 2016-03-31
# 9991 2018-06-21 2018-06-25
# 9992 2019-03-02 2019-03-02
# 9993 2019-06-19 2019-06-23
#
# [9994 rows x 2 columns]

# %%
df=df[['Order Date','Ship Date']]

# %%
df['order_year']=[str(i).split("-")[0] for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year
# 0 2016-03-18 2016-03-23       2016
# 1 2018-10-02 2018-10-09       2018
# 2 2019-03-23 2019-03-25       2019
# 3 2019-10-22 2019-10-24       2019
# 4 2019-11-17 2019-11-22       2019

# %%
df['order_Month']=[str(i).split("-")[1] for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month
# 0 2016-03-18 2016-03-23       2016          03
# 1 2018-10-02 2018-10-09       2018          10
# 2 2019-03-23 2019-03-25       2019          03
# 3 2019-10-22 2019-10-24       2019          10
# 4 2019-11-17 2019-11-22       2019          11

# %%
df["order_week"] = df["Order Date"].dt.week
# Out:
# C:\Users\PRASADH\AppData\Local\Temp\ipykernel_7468\1299727941.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["order_week"] = df["Order Date"].dt.week

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week
# 0 2016-03-18 2016-03-23       2016          03          11
# 1 2018-10-02 2018-10-09       2018          10          40
# 2 2019-03-23 2019-03-25       2019          03          12
# 3 2019-10-22 2019-10-24       2019          10          43
# 4 2019-11-17 2019-11-22       2019          11          46

# %%
df["order_day"] = df["Order Date"].dt.day

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17

# %%
df["order_dayname"] = df["Order Date"].dt.day_name()

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname
# 0        Friday
# 1       Tuesday
# 2      Saturday
# 3       Tuesday
# 4        Sunday

# %%
df['order_Repubilc_calender_day']=[(str(i).split("-")[1]==1 and str(i).split("-")[2]==26) for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day
# 0        Friday                        False
# 1       Tuesday                        False
# 2      Saturday                        False
# 3       Tuesday                        False
# 4        Sunday                        False

# %%
from pandas.tseries.offsets import BDay
b_day=pd.date_range("2016-03-18", periods=9994, freq=BDay())

# %%
b_day
# Out:
# DatetimeIndex(['2016-03-18', '2016-03-21', '2016-03-22', '2016-03-23',
#                '2016-03-24', '2016-03-25', '2016-03-28', '2016-03-29',
#                '2016-03-30', '2016-03-31',
#                ...
#                '2054-06-25', '2054-06-26', '2054-06-29', '2054-06-30',
#                '2054-07-01', '2054-07-02', '2054-07-03', '2054-07-06',
#                '2054-07-07', '2054-07-08'],
#               dtype='datetime64[ns]', length=9994, freq='B')

# %%
df["Bissiness_day"] =0
for i in df["Order Date"]:
    if i==list[b_day]:
        print("yes", i)
        df["Bissiness_day"] = i+1

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day
# 0        Friday                        False              0
# 1       Tuesday                        False              0
# 2      Saturday                        False              0
# 3       Tuesday                        False              0
# 4        Sunday                        False              0

# %%
df['order_Year_end']=[(str(i).split("-")[1]==12 and str(i).split("-")[2]==31) for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False

# %%
df['order_bisi_Year_end']=[(str(i).split("-")[1]==3 and str(i).split("-")[2]==31) for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end
# 0                False
# 1                False
# ...

# %%
df['order_quarter_end']=[(str(i).split("-")[1]==[3,6,9,12] and str(i).split("-")[2]==[31,30,30,31]) for i in df['Order Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end
# 0                False              False
# ...

# %%
df
# Out:
#      Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0    2016-03-18 2016-03-23       2016          03          11         18
# 1    2018-10-02 2018-10-09       2018          10          40          2
# 2    2019-03-23 2019-03-25       2019          03          12         23
# 3    2019-10-22 2019-10-24       2019          10          43         22
# 4    2019-11-17 2019-11-22       2019          11          46         17
# ...         ...        ...        ...         ...         ...        ...
# 9989 2016-09-26 2016-09-26       2016          09          39         26
# 9990 2016-03-31 2016-03-31       2016          03          13         31
# 9991 2018-06-21 2018-06-25       2018          06          25         21
# 9992 2019-03-02 2019-03-02       2019          03           9          2
# 9993 2019-06-19 2019-06-23       2019          06          25         19
#
#      order_dayname  order_Repubilc_calender_day  Bissiness_day  \
# ...

# %%
## for ship

# %%
df['ship_year']=[str(i).split("-")[0] for i in df['Ship Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year
# ...

# %%
df['ship_Month']=[str(i).split("-")[1] for i in df['Ship Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month
# ...

# %%
df['ship_day']=[str(i).split("-")[2] for i in df['Ship Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month     ship_day
# ...

# %%
df["ship_dayname"] = df["Ship Date"].dt.day_name()

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month     ship_day  \
# ...

# %%
df["ship_week"] = df["Ship Date"].dt.week
# Out:
# C:\Users\PRASADH\AppData\Local\Temp\ipykernel_7468\2480128161.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["ship_week"] = df["Ship Date"].dt.week

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month     ship_day  \
# ...

# %%
df['ship_Repubilc_calender_day']=[(str(i).split("-")[1]==1 and str(i).split("-")[2]==26) for i in df['Ship Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month     ship_day  \
# ...

# %%
df['ship_Year_end']=[(str(i).split("-")[1]==12 and str(i).split("-")[2]==31) for i in df['Ship Date']]

# %%
df.head()
# Out:
#   Order Date  Ship Date order_year order_Month  order_week  order_day  \
# 0 2016-03-18 2016-03-23       2016          03          11         18
# 1 2018-10-02 2018-10-09       2018          10          40          2
# 2 2019-03-23 2019-03-25       2019          03          12         23
# 3 2019-10-22 2019-10-24       2019          10          43         22
# 4 2019-11-17 2019-11-22       2019          11          46         17
#
#   order_dayname  order_Repubilc_calender_day  Bissiness_day  order_Year_end  \
# 0        Friday                        False              0           False
# 1       Tuesday                        False              0           False
# 2      Saturday                        False              0           False
# 3       Tuesday                        False              0           False
# 4        Sunday                        False              0           False
#
#    order_bisi_Year_end  order_quarter_end ship_year ship_Month     ship_day  \
# ...
